# %%
# Load Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# Load Data
df_songs = pd.read_csv("C:/fiifi/Shatta_Analytics_Project/Python_files/python_data_analysis/songs_fact.csv", index_col=0)
df_metrics = pd.read_csv("C:/fiifi/Shatta_Analytics_Project/Python_files/python_data_analysis/platform_metrics_dim.csv", index_col=0)
df_projects = pd.read_csv("C:/fiifi/Shatta_Analytics_Project/Python_files/python_data_analysis/project_dim.csv", index_col=0)

# %%
# Cleaning df_songs to create songs_fact(excel)
# Drop release_date_original and release_date_original.1
df_songs = df_songs.drop(columns=["release_date_original", "release_date_original.1"])

# Convert release_date  to datetime
df_songs["release_date"] = pd.to_datetime(df_songs["release_date"], dayfirst=False, errors="coerce")

# %%
df_songs.to_excel("songs_fact.xlsx", index=False)

# %%
# Exporting df_metrics to platform_metrics_dim(excel)
df_metrics.to_excel("platform_metrics_dim.xlsx", index=False)

# %%
# Clean and export df_projects to project_dim(excel)
df_projects["release_date"] = pd.to_datetime(df_projects["release_date"]).dt.date

df_projects.to_excel("project_dim.xlsx", index=False)
