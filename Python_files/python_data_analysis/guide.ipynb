# %% [markdown]
# ## QUESTIONS TO ANSWER IN THIS PROJECT
# 📅 Time Series & Growth Pattern Analysis
# |#|Question|Business Value|
# |-|--------|--------------|
# |1|What is the average views growth curve for a song? (Days 1-7, 8-30, 31-90, 90+)|Know when to promote vs stop promoting|
# |2|Which songs had "second wind" growth spikes months after release?|Identify resurgent songs for re-promotion|
# |3|What is the typical "peak velocity" (views/day at peak) for a hit vs flop?|Set realistic targets for new releases|
# |4|How does engagement rate (likes/views) decay over time?|Predict long-term fan loyalty|
#
# 📈 Predictive Analytics
# |#|Question|Business Value|
# |-|--------|--------------|
# |5|Can we predict total lifetime views based on first 7 days of performance?|Early identification of potential hits|
# |6|Which songs are "undervalued" (current views lower than predicted based on likes/comments)?|Find hidden gems for re-promotion|
# |7|What is the probability a new song will exceed 500k views based on release day and month?|Strategic release timing|
# |8|How many days until a song reaches 80% of its lifetime views?|Optimize promotion window length|
#
# 📊 Release Timing & Seasonality
# |#|Question|Business Value|
# |-|--------|--------------|
# |9|	What is the optimal day of week to release a song? (By 7-day, 30-day, and 90-day views)|Schedule releases for maximum momentum|
# |10|Are there seasonal patterns? (Which months historically perform best?)|Plan annual release calendar|
# |11|How does releasing on holidays affect performance?|Strategic holiday release decisions|
# |12|What is the ideal gap between releases? (Does releasing too close hurt performance?)|Optimize release cadence|
#
# 🔥 Performance Classification & Anomaly Detection
# |#|Question|Business Value|
# |-|--------|--------------|
# |13|Can we classify songs into tiers (Hit, Solid, Underperformer) based on view velocity?|Automated catalog prioritization|
# |14|Which songs are statistical anomalies (significantly outperforming similar songs released same month)?|Identify surprise hits worth studying|
# |15|What is the relationship between comment rate and long-term view growth?|Understand if comments drive or reflect popularity|
