# %% [markdown]
# ### Testing Grounds

# %%
print("This is a testing Ground")
# Out:
# This is a testing Ground

# %%
import pandas as pd

# %%
df = pd.read_csv("APIs\shatta_wale_data\shatta_wale_data_20260322.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1265 entries, 0 to 1264
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1265 non-null   object
#  1   release_date   1265 non-null   object
#  2   producer       1265 non-null   object
#  3   genre          1265 non-null   object
#  4   duration       1265 non-null   object
#  5   comment_count  1265 non-null   int64
#  6   like_count     1265 non-null   int64
#  7   view_count     1265 non-null   int64
#  8   video_url      1265 non-null   object
#  9   description    1144 non-null   object
#  10  audio          1265 non-null   bool
#  11  is_single      1265 non-null   bool
#  12  video_id       1265 non-null   object
# dtypes: bool(2), int64(3), object(8)
# memory usage: 111.3+ KB

# %%
pd.read_csv("APIs\shatta_wale_data\lastfm_tracks_20260322_140603.csv")
# Out:
#                              track_name  track_playcount  track_listeners  \
# 0                               Hossana             7528             1494
# 1                               Hol' It             6610             1481
# 2                      Baby (Chop Kiss)             5618             1437
# 3                        Dancehall King             6309             1348
# 4                                  Ayoo             6917             1284
# ..                                  ...              ...              ...
# 95                   My Mind Is Made Up              195               77
# 96                         STREET CROWN             6361               76
# 97                       So Real, So Me             2171               76
# 98  KING IN A LIFE. (African Dancehall)              843               73
# 99                         If I Collect              178               73
#
#                                             track_url  track_rank  album_name
# ...

# %%
pd.read_csv("APIs\shatta_wale_data\itunes_tracks_20260322_203158.csv")
# Out:
#                            track_name  artist_name  \
# 0    AIN'T NOBODY (feat. JOHN LEGEND)  Shatta Wale
# 1              Yawa Ni (shatta music)  Shatta Wale
# 2                              Danger  Shatta Wale
# 3                         Big Lie Dat  Shatta Wale
# 4                         Rise Anyway  Shatta Wale
# ..                                ...          ...
# 195         Pinga (feat. Shatta Wale)    DJ Breezy
# 196            Everybody Like My Ting  Shatta Wale
# 197                     Enter the Net  Shatta Wale
# 198                       Shatta City  Shatta Wale
# 199                  Baby (Chop Kiss)  Shatta Wale
#
#                                         album_name          release_date  \
# 0        AIN'T NOBODY (feat. JOHN LEGEND) - Single  2026-03-20T12:00:00Z
# 1               The Interface (Shatta Music Genre)  2026-02-19T12:00:00Z
# 2                                  Danger - Single  2026-02-16T12:00:00Z
# ...

# %%
from soundcloud import SoundCloudClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from soundcloud import SoundCloudClient
#
# ModuleNotFoundError: No module named 'soundcloud'

# %%
import pandas as pd
df = pd.read_csv("CSV_files\csv_files_utf8\songs_fact.csv", encoding="UTF8")

# %%
print("Total rows:", len(df))
print("\nRows with NULL/NaN song_id:", df['song_id'].isna().sum())
print("Rows with empty string song_id:", (df['song_id'] == '').sum())
print("Rows with 'null' as string:", (df['song_id'] == 'null').sum())
print("\nFirst 10 song_id values:")
print(df['song_id'].head(10))
print("\nData types:", df['song_id'].dtype)
# Out:
# Total rows: 1027
#
# Rows with NULL/NaN song_id: 58
# Rows with empty string song_id: 0
# Rows with 'null' as string: 0
#
# First 10 song_id values:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# Name: song_id, dtype: float64
#
# Data types: float64

# %%
df[960:1027]
# Out:
#       song_id  project_id                                  title artiste_name  \
# 960     961.0         1.0  It'S Not Over (Mix Masta Garzy Remix)  Shatta Wale
# 961     962.0         1.0               Jeje (Feat. Shatta Wale)   Sista Afia
# 962     963.0         1.0      Party Fi Life (Feat. Shatta Wale)  Shawn Storm
# 963     964.0         1.0            Too Big (Feat. Shatta Wale)     Maccasio
# 964     965.0         1.0          Atm Remix (Feat. Shatta Wale)     Alkaline
# ...       ...         ...                                    ...          ...
# 1022      NaN         NaN                                    NaN          NaN
# 1023      NaN         NaN                                    NaN          NaN
# 1024      NaN         NaN                                    NaN          NaN
# 1025      NaN         NaN                                    NaN          NaN
# 1026      NaN         NaN                                    NaN          NaN
#
# ...
